# %%
from docling.document_converter import DocumentConverter
from docling.datamodel.settings import settings

# Enable debug visualization
settings.debug.visualize_layout = True
settings.debug.visualize_raw_layout = True
settings.debug.visualize_ocr = True
settings.debug.visualize_tables = True
settings.debug.visualize_cells = True

# Set a custom debug output path (optional)
settings.debug.debug_output_path = "debug_output"

# Create converter and process document
source = "documents/H.R.1968 - Full-Year Continuing Appropriations and Extensions Act, 03-14-2025.pdf"
converter = DocumentConverter()
result = converter.convert(source)
print(result.document.export_to_markdown())

# Print conversion status
print(f"Conversion status: {result.status}")
# Out:
# <!-- image -->
#
# 119TH CONGRESS
#
# 1ST SESSION
#
# ## H. R. 1968
#
# ## AN ACT
#
# Making  further  continuing  appropriations  and  other  exten-
#
# sions  for  the  fiscal  year  ending  September  30,  2025, and for other purposes.
#
# Be it enacted by the Senate and House of Representa- 1
#
# tives of the United States of America in Congress assembled, 2
#
# VerDate Sep 11 2014
#
# 12:32 Mar 11, 2025
#
# Jkt 000000
#
# PO 00000
#
# Frm 00001
#
# Fmt 6652
#
# Sfmt 6201
#
# Z:\XMLBILLS\H1968.EH
#
# CLERK
#
# &lt;unknown&gt;
#
# VerDate Sep 11 2014
#
# 2
#
# • HR 1968  EH
#
# SECTION 1. SHORT TITLE. 1
#
# This Act may be cited as the ''Full-Year Continuing 2
#
# Appropriations and Extensions Act, 2025''. 3
#
# SEC. 2. TABLE OF CONTENTS. 4
#
# The table of contents of this Act is as follows: 5
#
# Sec. 1.
#
# Short title.
#
# Sec. 2.
#
# Table of contents.
#
# Sec. 3.
#
# References.
#
# DIVISION  A-FULL-YEAR CONTINUING APPROPRIATIONS ACT, 2025
#
# TITLE I-GENERAL PROVISIONS
#
# ...
